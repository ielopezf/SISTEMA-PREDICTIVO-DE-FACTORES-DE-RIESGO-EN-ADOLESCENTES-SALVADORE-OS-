# %% [markdown]
# # 00 — Consolidación de datos MAG
# **CRISP-DM: Comprensión de los datos**
#
# El equipo ya generó `precios_consolidados.xlsx` a partir de los informes diarios del MAG
# (script `Extraer datos/extraer_precios.py`). Este notebook documenta y verifica ese proceso.
# Colocar el consolidado en `data/interim/`.

# %%
# Setup común
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / "src"))  # importar paquete sin instalar

import pandas as pd
import numpy as np
from prediccion_precios import config
# TODO: descomentar al implementar los módulos
# from prediccion_precios import data_loading, eda, preprocessing, features
# from prediccion_precios import models_baseline, evaluation, interpretability

# %% [markdown]
# ## 1. Cargar el consolidado y verificar dimensiones

# %%
# df = data_loading.cargar_precios_consolidados()
# print(df.shape)   # esperado ~ (11648, 8)
# df.head()

# %% [markdown]
# ## 2. Ficha del dataset (fuente, tamaño, variables, licencia)
# > Requisito Etapa 1: *Recolección y descripción del dataset*.

# %%
# ficha = data_loading.describir_dataset(df)
# ficha
